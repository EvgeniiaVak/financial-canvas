# %%
# %reload_ext autoreload
# %autoreload 2

from financial_canvas.figures.Candlestick import Candlestick
from financial_canvas import indicators_glyphs
import yfinance as yf
from bokeh.io import output_notebook, show

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
ticker = yf.Ticker("AAPL")
df = ticker.history(start='2020-01-02', end='2021-01-01')
df.columns = map(str.lower, df.columns)
df
# Out:
#                   open        high         low       close     volume  \
# Date
# 2020-01-02   73.082501   74.158118   72.823469   74.096443  135480400
# 2020-01-03   73.307008   74.153188   73.146654   73.376083  146322800
# 2020-01-06   72.478106   74.000243   72.221535   73.960770  118387200
# 2020-01-07   73.970641   74.232143   73.388432   73.612930  108872000
# 2020-01-08   73.309478   75.105456   73.309478   74.797081  132079200
# ...                ...         ...         ...         ...        ...
# 2020-12-24  130.705875  132.835866  130.486902  131.352829   54930100
# 2020-12-28  133.363396  136.697720  132.885629  136.050766  124486200
# 2020-12-29  137.404410  138.140939  133.711753  134.239273  121047300
# 2020-12-30  134.945952  135.354039  132.776139  133.094650   96452100
# 2020-12-31  133.452972  134.109889  131.104008  132.069473   99116600
#
#             dividends  stock splits
# Date
# 2020-01-02        0.0           0.0
# 2020-01-03        0.0           0.0
# ...

# %%
candlestick = Candlestick(df, figure_args={"plot_height": 600})
indicators_glyphs.line_circles(candlestick, 'open')
show(candlestick.p)
# Out:
#   <div class="bk-root" id="2453ca2f-6b5d-4f2a-a5da-9b904ceb3b6e" data-root-id="1009"></div>
